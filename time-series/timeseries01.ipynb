# %%
import pandas as pd

df= pd.read_csv("stocks.csv")

df.head()
# Out:
#                Date Symbol    Open    High     Low   Close      Volume
# 0  2020-03-13 08-PM  ALTA3  129.94  131.82  126.87  128.71  1940673.93
# 1  2020-03-13 07-PM  ALTA3  119.51  132.02  117.10  129.94  7579741.09
# 2  2020-03-13 06-PM  ALTA3  124.47  124.85  115.50  119.51  4898735.81
# 3  2020-03-13 05-PM  ALTA3  124.08  127.42  121.63  124.47  2753450.92
# 4  2020-03-13 04-PM  ALTA3  124.85  129.51  120.17  124.08  4461424.71

# %%
df.loc[0, "Date"]
# Out:
# '2020-03-13 08-PM'

# %%
df.loc[0, "Date"].day_name() # THIS WILL CAUSE AN ERROR!
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [7], line 1
# ----> 1 df.loc[0, "Date"].day_name() # THIS WILL CAUSE AN ERROR!
#
# AttributeError: 'str' object has no attribute 'day_name'

# %%
df["Date"] = pd.to_datetime(df["Date"]) # THIS WILL STILL CAUSE AN ERROR!
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/tslib.pyx:605, in pandas._libs.tslib.array_to_datetime()
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/tslibs/parsing.pyx:320, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File /usr/local/lib/python3.10/dist-packages/dateutil/parser/_parser.py:1368, in parse(timestr, parserinfo, **kwargs)
#    1367 else:
# -> 1368     return DEFAULTPARSER.parse(timestr, **kwargs)
#
# File /usr/local/lib/python3.10/dist-packages/dateutil/parser/_parser.py:643, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     642 if res is None:
# --> 643     raise ParserError("Unknown string format: %s", timestr)
#     645 if len(res) == 0:
#
# ParserError: Unknown string format: 2020-03-13 08-PM
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/tslib.pyx:616, in pandas._libs.tslib.array_to_datetime()
#
# TypeError: invalid string coercion to datetime for "2020-03-13 08-PM" at position 0
#
# During handling of the above exception, another exception occurred:
#
# ParserError                               Traceback (most recent call last)
# Cell In [4], line 1
# ----> 1 df["Date"] = pd.to_datetime(df["Date"]) # THIS WILL STILL CAUSE AN ERROR!
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:1068, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1066         result = arg.map(cache_array)
#    1067     else:
# -> 1068         values = convert_listlike(arg._values, format)
#    1069         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1070 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:438, in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     436 assert format is None or infer_datetime_format
#     437 utc = tz == "utc"
# --> 438 result, tz_parsed = objects_to_datetime64ns(
#     439     arg,
#     440     dayfirst=dayfirst,
#     441     yearfirst=yearfirst,
#     442     utc=utc,
#     443     errors=errors,
#     444     require_iso8601=require_iso8601,
#     445     allow_object=True,
#     446 )
#     448 if tz_parsed is not None:
#     449     # We can take a shortcut since the datetime64 numpy array
#     450     # is in UTC
#     451     dta = DatetimeArray(result, dtype=tz_to_dtype(tz_parsed))
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/arrays/datetimes.py:2177, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2175 order: Literal["F", "C"] = "F" if flags.f_contiguous else "C"
#    2176 try:
# -> 2177     result, tz_parsed = tslib.array_to_datetime(
#    2178         data.ravel("K"),
#    2179         errors=errors,
#    2180         utc=utc,
#    2181         dayfirst=dayfirst,
#    2182         yearfirst=yearfirst,
#    2183         require_iso8601=require_iso8601,
#    2184         allow_mixed=allow_mixed,
#    2185     )
#    2186     result = result.reshape(data.shape, order=order)
#    2187 except OverflowError as err:
#    2188     # Exception is raised when a part of date is greater than 32 bit signed int
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/tslib.pyx:427, in pandas._libs.tslib.array_to_datetime()
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/tslib.pyx:683, in pandas._libs.tslib.array_to_datetime()
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/tslib.pyx:829, in pandas._libs.tslib._array_to_datetime_object()
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/tslib.pyx:819, in pandas._libs.tslib._array_to_datetime_object()
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/tslibs/parsing.pyx:320, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File /usr/local/lib/python3.10/dist-packages/dateutil/parser/_parser.py:1368, in parse(timestr, parserinfo, **kwargs)
#    1366     return parser(parserinfo).parse(timestr, **kwargs)
#    1367 else:
# -> 1368     return DEFAULTPARSER.parse(timestr, **kwargs)
#
# File /usr/local/lib/python3.10/dist-packages/dateutil/parser/_parser.py:643, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     640 res, skipped_tokens = self._parse(timestr, **kwargs)
#     642 if res is None:
# --> 643     raise ParserError("Unknown string format: %s", timestr)
#     645 if len(res) == 0:
#     646     raise ParserError("String does not contain a date: %s", timestr)
#
# ParserError: Unknown string format: 2020-03-13 08-PM present at position 0

# %%
df["Date"]
# Out:
# 0        2020-03-13 08-PM
# 1        2020-03-13 07-PM
# 2        2020-03-13 06-PM
# 3        2020-03-13 05-PM
# 4        2020-03-13 04-PM
#                ...
# 23669    2017-07-01 03-PM
# 23670    2017-07-01 02-PM
# 23671    2017-07-01 01-PM
# 23672    2017-07-01 12-PM
# 23673    2017-07-01 11-AM
# Name: Date, Length: 23674, dtype: object

# %%
df.loc[0, "Date"].day_name()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [9], line 1
# ----> 1 df.loc[0, "Date"].day_name()
#
# AttributeError: 'str' object has no attribute 'day_name'

# %%
df["Date"] = pd.to_datetime(df["Date"], format='%Y-%m-%d %I-%p')

# %%
df["Date"]
# Out:
# 0       2020-03-13 20:00:00
# 1       2020-03-13 19:00:00
# 2       2020-03-13 18:00:00
# 3       2020-03-13 17:00:00
# 4       2020-03-13 16:00:00
#                 ...
# 23669   2017-07-01 15:00:00
# 23670   2017-07-01 14:00:00
# 23671   2017-07-01 13:00:00
# 23672   2017-07-01 12:00:00
# 23673   2017-07-01 11:00:00
# Name: Date, Length: 23674, dtype: datetime64[ns]

# %%
df.loc[0, "Date"].day_name()
# Out:
# 'Friday'

# %%
import pandas as pd
from datetime import datetime

# `timelord` is set to equal a lambda function, which is a shorthand function
# what it will do is pass each string in the "date" column against the datetime.strptime method 
# and the format string we already made
timelord= lambda eachdatestr: datetime.strptime(eachdatestr, "%Y-%m-%d %I-%p")

df= pd.read_csv("stocks.csv", parse_dates=["Date"], date_parser=timelord)

df.head()
# Out:
#                  Date Symbol    Open    High     Low   Close      Volume
# 0 2020-03-13 20:00:00  ALTA3  129.94  131.82  126.87  128.71  1940673.93
# 1 2020-03-13 19:00:00  ALTA3  119.51  132.02  117.10  129.94  7579741.09
# 2 2020-03-13 18:00:00  ALTA3  124.47  124.85  115.50  119.51  4898735.81
# 3 2020-03-13 17:00:00  ALTA3  124.08  127.42  121.63  124.47  2753450.92
# 4 2020-03-13 16:00:00  ALTA3  124.85  129.51  120.17  124.08  4461424.71

# %%
# the "Date" column is entirely datetime data, so we can use the "dt" method against it
df["Date"].dt.day_name()
# Out:
# 0          Friday
# 1          Friday
# 2          Friday
# 3          Friday
# 4          Friday
#            ...
# 23669    Saturday
# 23670    Saturday
# 23671    Saturday
# 23672    Saturday
# 23673    Saturday
# Name: Date, Length: 23674, dtype: object

# %%
#adding a column with parsed data
df["Week Day"]= df["Date"].dt.day_name()
df
# Out:
#                      Date Symbol    Open    High     Low   Close      Volume  \
# 0     2020-03-13 20:00:00  ALTA3  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ALTA3  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ALTA3  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ALTA3  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ALTA3  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...    ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ALTA3  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ALTA3  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ALTA3  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ALTA3  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ALTA3  279.98  279.99  272.10  275.01   679358.87
#
#        Week Day
# 0        Friday
# 1        Friday
# 2        Friday
# 3        Friday
# 4        Friday
# ...         ...
# 23669  Saturday
# 23670  Saturday
# 23671  Saturday
# 23672  Saturday
# 23673  Saturday
#
# [23674 rows x 8 columns]

# %%
df["Date"].min()
# Out:
# Timestamp('2017-07-01 11:00:00')

# %%
df["Date"].max()
# Out:
# Timestamp('2020-03-13 20:00:00')

# %%
df["Date"].max() - df["Date"].min()
# Out:
# Timedelta('986 days 09:00:00')

# %%
filt= df["Date"] >= "2020"
# this will create a range of true/false values for the "Date" column-- 
# these can then be compared against our dataframe with .loc()
df.loc[filt]
# Out:
#                     Date Symbol    Open    High     Low   Close      Volume  \
# 0    2020-03-13 20:00:00  ALTA3  129.94  131.82  126.87  128.71  1940673.93
# 1    2020-03-13 19:00:00  ALTA3  119.51  132.02  117.10  129.94  7579741.09
# 2    2020-03-13 18:00:00  ALTA3  124.47  124.85  115.50  119.51  4898735.81
# 3    2020-03-13 17:00:00  ALTA3  124.08  127.42  121.63  124.47  2753450.92
# 4    2020-03-13 16:00:00  ALTA3  124.85  129.51  120.17  124.08  4461424.71
# ...                  ...    ...     ...     ...     ...     ...         ...
# 1744 2020-01-01 04:00:00  ALTA3  129.57  130.00  129.50  129.56   702786.82
# 1745 2020-01-01 03:00:00  ALTA3  130.37  130.44  129.38  129.57   496704.23
# 1746 2020-01-01 02:00:00  ALTA3  130.14  130.50  129.91  130.37   396315.72
# 1747 2020-01-01 01:00:00  ALTA3  128.34  130.14  128.32  130.14   635419.40
# 1748 2020-01-01 00:00:00  ALTA3  128.54  128.54  128.12  128.34   245119.91
#
#        Week Day
# 0        Friday
# 1        Friday
# 2        Friday
# 3        Friday
# 4        Friday
# ...         ...
# 1744  Wednesday
# 1745  Wednesday
# 1746  Wednesday
# 1747  Wednesday
# 1748  Wednesday
#
# [1749 rows x 8 columns]

# %%
filt2= (df["Date"] >= pd.to_datetime("2019-01-01")) & (df["Date"] < pd.to_datetime("2019-02-01"))
df.loc[filt2]
# Out:
#                      Date Symbol    Open    High     Low   Close      Volume  \
# 9765  2019-01-31 23:00:00  ALTA3  106.24  106.24  105.53  105.79   154196.70
# 9766  2019-01-31 22:00:00  ALTA3  105.75  106.35  105.61  106.24   287372.14
# 9767  2019-01-31 21:00:00  ALTA3  106.23  106.23  105.64  105.75   329152.63
# 9768  2019-01-31 20:00:00  ALTA3  105.71  106.25  105.49  106.23   460235.89
# 9769  2019-01-31 19:00:00  ALTA3  105.11  105.84  105.05  105.71   440680.10
# ...                   ...    ...     ...     ...     ...     ...         ...
# 10504 2019-01-01 04:00:00  ALTA3  130.75  133.96  130.74  131.96  2791135.37
# 10505 2019-01-01 03:00:00  ALTA3  130.06  130.79  130.06  130.75   503732.63
# 10506 2019-01-01 02:00:00  ALTA3  130.79  130.88  129.55  130.06   838183.43
# 10507 2019-01-01 01:00:00  ALTA3  131.62  131.62  130.77  130.79   434917.99
# 10508 2019-01-01 00:00:00  ALTA3  130.53  131.91  130.48  131.62  1067136.21
#
#        Week Day
# 9765   Thursday
# 9766   Thursday
# 9767   Thursday
# 9768   Thursday
# 9769   Thursday
# ...         ...
# 10504   Tuesday
# 10505   Tuesday
# 10506   Tuesday
# 10507   Tuesday
# 10508   Tuesday
#
# [744 rows x 8 columns]

# %%
df.set_index("Date", inplace=True)
df
# Out:
#                     Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-03-13 20:00:00  ALTA3  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 19:00:00  ALTA3  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 18:00:00  ALTA3  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 17:00:00  ALTA3  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 16:00:00  ALTA3  124.85  129.51  120.17  124.08  4461424.71
# ...                    ...     ...     ...     ...     ...         ...
# 2017-07-01 15:00:00  ALTA3  265.74  272.74  265.00  272.57  1500282.55
# 2017-07-01 14:00:00  ALTA3  268.79  269.90  265.00  265.74  1702536.85
# 2017-07-01 13:00:00  ALTA3  274.83  274.93  265.00  268.79  3010787.99
# 2017-07-01 12:00:00  ALTA3  275.01  275.01  271.00  274.83   824362.87
# 2017-07-01 11:00:00  ALTA3  279.98  279.99  272.10  275.01   679358.87
#
#                      Week Day
# Date
# 2020-03-13 20:00:00    Friday
# 2020-03-13 19:00:00    Friday
# 2020-03-13 18:00:00    Friday
# 2020-03-13 17:00:00    Friday
# 2020-03-13 16:00:00    Friday
# ...                       ...
# 2017-07-01 15:00:00  Saturday
# 2017-07-01 14:00:00  Saturday
# 2017-07-01 13:00:00  Saturday
# 2017-07-01 12:00:00  Saturday
# 2017-07-01 11:00:00  Saturday
#
# [23674 rows x 7 columns]

# %%
df.loc["2019"]
# Out:
#                     Symbol    Open    High     Low   Close      Volume  \
# Date
# 2019-12-31 23:00:00  ALTA3  128.33  128.69  128.14  128.54   440678.91
# 2019-12-31 22:00:00  ALTA3  128.38  128.69  127.95  128.33   554646.02
# 2019-12-31 21:00:00  ALTA3  127.86  128.43  127.72  128.38   350155.69
# 2019-12-31 20:00:00  ALTA3  127.84  128.34  127.71  127.86   428183.38
# 2019-12-31 19:00:00  ALTA3  128.69  128.69  127.60  127.84  1169847.84
# ...                    ...     ...     ...     ...     ...         ...
# 2019-01-01 04:00:00  ALTA3  130.75  133.96  130.74  131.96  2791135.37
# 2019-01-01 03:00:00  ALTA3  130.06  130.79  130.06  130.75   503732.63
# 2019-01-01 02:00:00  ALTA3  130.79  130.88  129.55  130.06   838183.43
# 2019-01-01 01:00:00  ALTA3  131.62  131.62  130.77  130.79   434917.99
# 2019-01-01 00:00:00  ALTA3  130.53  131.91  130.48  131.62  1067136.21
#
#                     Week Day
# Date
# 2019-12-31 23:00:00  Tuesday
# 2019-12-31 22:00:00  Tuesday
# 2019-12-31 21:00:00  Tuesday
# 2019-12-31 20:00:00  Tuesday
# 2019-12-31 19:00:00  Tuesday
# ...                      ...
# 2019-01-01 04:00:00  Tuesday
# 2019-01-01 03:00:00  Tuesday
# 2019-01-01 02:00:00  Tuesday
# 2019-01-01 01:00:00  Tuesday
# 2019-01-01 00:00:00  Tuesday
#
# [8760 rows x 7 columns]

# %%
df.loc["2020-01":"2020-03"]
# Out:
#                     Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-03-13 20:00:00  ALTA3  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 19:00:00  ALTA3  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 18:00:00  ALTA3  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 17:00:00  ALTA3  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 16:00:00  ALTA3  124.85  129.51  120.17  124.08  4461424.71
# ...                    ...     ...     ...     ...     ...         ...
# 2020-01-01 04:00:00  ALTA3  129.57  130.00  129.50  129.56   702786.82
# 2020-01-01 03:00:00  ALTA3  130.37  130.44  129.38  129.57   496704.23
# 2020-01-01 02:00:00  ALTA3  130.14  130.50  129.91  130.37   396315.72
# 2020-01-01 01:00:00  ALTA3  128.34  130.14  128.32  130.14   635419.40
# 2020-01-01 00:00:00  ALTA3  128.54  128.54  128.12  128.34   245119.91
#
#                       Week Day
# Date
# 2020-03-13 20:00:00     Friday
# 2020-03-13 19:00:00     Friday
# 2020-03-13 18:00:00     Friday
# 2020-03-13 17:00:00     Friday
# 2020-03-13 16:00:00     Friday
# ...                        ...
# 2020-01-01 04:00:00  Wednesday
# 2020-01-01 03:00:00  Wednesday
# 2020-01-01 02:00:00  Wednesday
# 2020-01-01 01:00:00  Wednesday
# 2020-01-01 00:00:00  Wednesday
#
# [1749 rows x 7 columns]

# %%
df.loc["2020-01":"2020-03"]["Close"].mean()
# Out:
# 197.56875929102344

# %%
df.loc["2020-01"]["High"]
# Out:
# Date
# 2020-01-31 23:00:00    181.73
# 2020-01-31 22:00:00    182.24
# 2020-01-31 21:00:00    181.04
# 2020-01-31 20:00:00    180.51
# 2020-01-31 19:00:00    179.57
#                         ...
# 2020-01-01 04:00:00    130.00
# 2020-01-01 03:00:00    130.44
# 2020-01-01 02:00:00    130.50
# 2020-01-01 01:00:00    130.14
# 2020-01-01 00:00:00    128.54
# Name: High, Length: 744, dtype: float64

# %%
df.loc["2020-01"]["High"].max()
# Out:
# 186.89

# %%
# https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#dateoffset-objects

# df["High"].resample("2D") <-- this would sample every other day
# df["High"].resample("W") <-- this would sample every week
# df["High"].resample("3W") <-- this would sample every three weeks

# return the max value of "High" for every 24 hour period!
highs= df["High"].resample("D").max()
highs

# %%
from matplotlib import pyplot as plt

plt.plot(highs)
plt.show()
