# %%
import pandas as pd

# %%
cheese_df = pd.read_csv('/home/student/mycode/warmup/annualcheeseconsumed.csv')

cheese_df
# Out:
#     Year  Cheddar  American Other  Mozzarella  Italian other  Swiss  Brick  \
# 0   1970     5.79            1.20        1.19           0.87   0.88   0.10
# 1   1971     5.91            1.42        1.38           0.92   0.94   0.11
# 2   1972     6.01            1.67        1.57           1.02   1.06   0.10
# 3   1973     6.07            1.76        1.76           1.03   1.06   0.11
# 4   1974     6.31            2.16        1.86           1.09   1.18   0.11
# 5   1975     6.04            2.11        2.11           1.12   1.09   0.09
# 6   1976     6.45            2.44        2.31           1.24   1.25   0.09
# 7   1977     6.80            2.42        2.46           1.26   1.21   0.07
# 8   1978     6.94            2.59        2.68           1.37   1.33   0.08
# 9   1979     6.93            2.67        2.80           1.42   1.35   0.06
# 10  1980     6.84            2.78        3.01           1.42   1.32   0.07
# ...

# %%
cheese_df = cheese_df.set_index('Year')

cheese_df.head()
# Out:
#       Cheddar  American Other  Mozzarella  Italian other  Swiss  Brick  \
# Year
# 1970     5.79            1.20        1.19           0.87   0.88   0.10
# 1971     5.91            1.42        1.38           0.92   0.94   0.11
# 1972     6.01            1.67        1.57           1.02   1.06   0.10
# 1973     6.07            1.76        1.76           1.03   1.06   0.11
# 1974     6.31            2.16        1.86           1.09   1.18   0.11
#
#       Muenster  Cream and Neufchatel  Blue  Other Dairy Cheese  \
# Year
# 1970      0.17                  0.61  0.15                0.41
# 1971      0.19                  0.62  0.15                0.41
# 1972      0.22                  0.63  0.17                0.56
# 1973      0.21                  0.66  0.18                0.65
# 1974      0.23                  0.70  0.16                0.61
#
#       Processed Cheese  Foods and spreads  Total American Chese  \
# Year
# 1970              3.32               2.20                  7.00
# ...

# %%
short_cheese_df = cheese_df[["Cheddar", "Swiss", "Muenster"]]

short_cheese_df.head()
# Out:
#       Cheddar  Swiss  Muenster
# Year
# 1970     5.79   0.88      0.17
# 1971     5.91   0.94      0.19
# 1972     6.01   1.06      0.22
# 1973     6.07   1.06      0.21
# 1974     6.31   1.18      0.23

# %%
sort_shcheese_df = short_cheese_df.sort_values(["Year"], ascending=False)

sort_shcheese_df.head()
# Out:
#       Cheddar  Swiss  Muenster
# Year
# 2017    11.07   1.05      0.53
# 2016    10.39   1.06      0.52
# 2015    10.17   1.05      0.50
# 2014     9.85   1.02      0.47
# 2013     9.64   1.00      0.48

# %%
sort_shcheese_df.mean()
# Out:
# Cheddar     8.889167
# Swiss       1.155417
# Muenster    0.340208
# dtype: float64
