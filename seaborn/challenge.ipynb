# %%
import csv
import pandas as pd
# python3 -m pip install np
import numpy as np
# python3 -m pip install matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

columns = ["decade", "deaths", "country"]
df = pd.read_csv("/home/student/mycode/graphing/trials.csv", delimiter=',', usecols=columns)
print(df)
# Out:
#        decade  deaths  country
# 0        1520     1.0  Estonia
# 1        1530     1.0  Estonia
# 2        1540     5.0  Estonia
# 3        1580     5.0  Estonia
# 4        1590     0.0  Estonia
# ...       ...     ...      ...
# 10935    1740     0.0  Germany
# 10936    1750     0.0  Germany
# 10937    1760     0.0  Germany
# 10938    1770     0.0  Germany
# 10939    1790     0.0  Germany
#
# [10940 rows x 3 columns]

# %%
df.groupby(['decade']).sum()
# Out:
# /tmp/ipykernel_19106/445637108.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['decade']).sum()
#         deaths
# decade
# 1300      38.0
# 1310     102.0
# 1320       5.0
# 1330      23.0
# 1340       0.0
# 1350       0.0
# 1360       1.0
# 1370       5.0
# 1380       2.0
# 1390      14.0
# 1400      54.0
# 1410      46.0
# 1420     421.0
# 1430      78.0
# 1440      87.0
# 1450      75.0
# 1460      39.0
# 1470      35.0
# 1480     188.0
# 1490      98.0
# 1500      38.0
# 1510      37.0
# 1520      46.0
# 1530      60.0
# 1540     105.0
# 1550     162.0
# 1560     243.0
# 1570     485.0
# 1580    1177.0
# 1590    1923.0
# 1600    1081.0
# 1610    1966.0
# 1620    2378.0
# 1630    1402.0
# 1640     986.0
# 1650     951.0
# 1660     562.0
# 1670     499.0
# 1680     193.0
# ...

# %%
sns.relplot(x="decade", y=("deaths"), hue="country", style="country", data=df);
plt.show()

# %%
plt.savefig("trials.pdf")

# %%
sns.relplot(x="decade", y="country", hue="deaths", style="country", data=df);
plt.show()
